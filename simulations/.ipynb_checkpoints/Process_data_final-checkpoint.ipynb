# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
from sklearn.metrics import mean_squared_error
import scipy.stats as stats
from scipy.stats import norm
import statsmodels.api as sm
import pingouin as pg

# %% [markdown]
# ## 2 dim correlated

# %%
data = pd.read_csv("results/results_2d_correlated_1discrete.csv")
data = data[(data["tau"]==0.9)&(data["n"]==10000)]
# kNN
data_group = data.drop(columns=["seed","p","time","tau"]).groupby(["n","Method","num_bin"])
bias = data_group.mean().reset_index()
std = data_group.std().reset_index()
RMSE = np.sqrt(data_group.apply(lambda x: (x**2).mean())).reset_index()
data_group_other = data[np.isnan(data["num_bin"])].drop(columns=["seed","p","tau","num_bin","time"]).groupby(["n","Method"])
bias_other = data_group_other.mean().reset_index()
std_other = data_group_other.std().reset_index()
RMSE_other = np.sqrt(data_group_other.apply(lambda x: (x**2).mean())).reset_index()

num_bin = 8
bias = bias[bias["num_bin"]==num_bin]
std = std[std["num_bin"]==num_bin]
RMSE = RMSE[RMSE["num_bin"]==num_bin]
methods_to_filter = ["mRock_kNN_global_linear_Neyman","mRock_kNN_bs_Neyman"]
bias_irock = bias[(bias["Method"].isin(methods_to_filter))].drop(columns="num_bin")#.set_index(['n','Method'])
bias_2step = bias_other[bias_other["Method"].isin(["two_step_Neyman","Average of linear quantiles"])]
# bias_2step["Method"]="two-step"
bias_wide = pd.concat([bias_irock,bias_2step])
# bias_wide = bias_wide.reset_index()
replacements={"mRock_kNN_global_linear_Neyman":"i-Rock w. linear quantile",
    "mRock_kNN_bs_Neyman":"i-Rock w. B-spline quantile",
                      #"local_adjust":"i-Rock w. local linear quantile (adjusted)",
                      "two_step_Neyman":"two-step"}
bias_wide["Method"] = bias_wide["Method"].replace(replacements)
bias_long = pd.melt(bias_wide.drop(columns='n'), id_vars=['Method'])
std_irock = std[(std["Method"].isin(methods_to_filter))].drop(columns="num_bin")
std_2step = std_other[std_other["Method"].isin(["two_step_Neyman"])]
std_wide = pd.concat([std_irock,std_2step])
std_wide["Method"] = std_wide["Method"].replace(replacements)
std_long = pd.melt(std_wide.drop(columns='n'), id_vars=['Method'])
bias_std = bias_long
bias_std["value"] = bias_long["value"]/std_long["value"]
replacements={"beta0":r"$\beta_0$",
             "beta1":r"$\beta_1$",
             "beta2":r"$\beta_2$"}
bias_std["variable"] = bias_std["variable"].replace(replacements)
RMSE_irock = RMSE[(RMSE["Method"].isin(methods_to_filter))].drop(columns="num_bin")
RMSE_2step = RMSE_other[(RMSE_other["Method"]=="two_step_Neyman")].drop(columns=["Method","n"]).reset_index(drop=True)
RMSE_gl = RMSE_2step/RMSE_irock[RMSE_irock["Method"]=="mRock_kNN_global_linear_Neyman"].drop(columns=["Method","n"]).reset_index(drop=True)
RMSE_gl["Method"]="i-Rock w. linear quantile"
#RMSE_gl_ad = RMSE_2step/RMSE_irock[RMSE_irock["Method"]=="global_linear_adjust"].drop(columns=["Method","n"]).reset_index(drop=True)
#RMSE_gl_ad["Method"]="i-Rock w. linear quantile (adjusted)"
#RMSE_lc = RMSE_2step/RMSE_irock[RMSE_irock["Method"]=="local_adjust"].drop(columns=["Method","n"]).reset_index(drop=True)
#RMSE_lc["Method"]="i-Rock w. local linear quantile (adjusted)"
RMSE_bs = RMSE_2step/RMSE_irock[RMSE_irock["Method"]=="mRock_kNN_bs_Neyman"].drop(columns=["Method","n"]).reset_index(drop=True)
RMSE_bs["Method"]="i-Rock w. B-spline quantile"
RMSE_mean_quantile = RMSE_2step/RMSE_other[(RMSE_other["Method"]=="Average of linear quantiles")].drop(columns=["Method","n"]).reset_index(drop=True)
RMSE_mean_quantile["Method"]="quantile average"
RMSE_wide = pd.concat([RMSE_gl,RMSE_bs,RMSE_mean_quantile])
RMSE_long = pd.melt(RMSE_wide, id_vars=['Method'])
replacements={"beta0":r"$\beta_0$",
             "beta1":r"$\beta_1$",
             "beta2":r"$\beta_2$"}
RMSE_long["variable"] = RMSE_long["variable"].replace(replacements)

# %%
fig = plt.figure(figsize=(9, 4))
ax = fig.add_subplot(1,2,1)
custom_colors = {
    'i-Rock w. linear quantile': (0.21568627450980393, 0.49411764705882355, 0.7215686274509804),   
    'i-Rock w. B-spline quantile': (1.0, 0.4980392156862745, 0.0),  
    'two-step': (0.30196078431372547, 0.6862745098039216, 0.2901960784313726),
    # 'quantile average': 'k'
}
custom_order = ['i-Rock w. linear quantile', 'i-Rock w. B-spline quantile','two-step']
sns.barplot(data=bias_std, x='variable', y='value', hue='Method', palette=custom_colors, hue_order=custom_order)
# Add labels
plt.xlabel('Coefficients')
plt.ylabel('Relative bias')
ax.legend_.remove()
#plt.legend()#title='Method')
#ax.legend_.remove()

ax = fig.add_subplot(1,2,2)
custom_colors = {
    'i-Rock w. linear quantile': (0.21568627450980393, 0.49411764705882355, 0.7215686274509804),   
    'i-Rock w. B-spline quantile': (1.0, 0.4980392156862745, 0.0),
    # 'quantile average': 'k'
}
custom_order = ['i-Rock w. linear quantile', 'i-Rock w. B-spline quantile']
sns.barplot(data=RMSE_long, x='variable', y='value', hue='Method',palette=custom_colors, hue_order=custom_order)
# Set y-axis limits
#plt.ylim(0, 2)
ax.axhline(y=1, color=(0.30196078431372547, 0.6862745098039216, 0.2901960784313726), linestyle='--',label='two-step')
ax.legend_.remove()
# Add labels and a legend
# plt.xlabel('Coefficients')
# plt.ylabel('RMSE ratio')
# handles, labels = ax.get_legend_handles_labels()
# new_order = [1, 2, 0]  # Assuming 'two-step' is the second entry
# ax.legend([handles[i] for i in new_order], [labels[i] for i in new_order], title='Method')
fig.tight_layout()
plt.savefig("2dim_correlated_n10000_tau9.pdf", format="pdf")

# %%
1.6*np.sqrt(2)*(np.sqrt(10000)/np.log(10000))**(1/2)
# Out:
# 7.455849628554499

# %% [markdown]
# ## 2 dim nonlinear

# %%
## correspond to "simulation_3d_nl_disjoint.R"
data_quant = pd.read_csv("results/results_2d_nl_mean_quantile.csv")
data_other = pd.read_csv("results/results_2d_nl_disjoint_final.csv")
data = pd.concat([data_quant,data_other])
data = data[(data["tau"]==0.9)&(data["n"]==10000)]
# kNN
data_group = data.drop(columns=["seed","p","time","tau"]).groupby(["n","Method","num_bin"])
bias = data_group.mean().reset_index()
std = data_group.std().reset_index()
RMSE = np.sqrt(data_group.apply(lambda x: (x**2).mean())).reset_index()
data_group_other = data[np.isnan(data["num_bin"])].drop(columns=["seed","p","tau","num_bin","time"]).groupby(["n","Method"])
bias_other = data_group_other.mean().reset_index()
std_other = data_group_other.std().reset_index()
RMSE_other = np.sqrt(data_group_other.apply(lambda x: (x**2).mean())).reset_index()

num_bin = 7
bias = bias[bias["num_bin"]==num_bin]
std = std[std["num_bin"]==num_bin]
RMSE = RMSE[RMSE["num_bin"]==num_bin]
methods_to_filter = ["mRock_kNN_global_linear_Neyman","mRock_kNN_global_bs_Neyman"]
bias_irock = bias[(bias["Method"].isin(methods_to_filter))].drop(columns="num_bin")#.set_index(['n','Method'])
bias_2step = bias_other[bias_other["Method"].isin(["two_step_Neyman","Average of linear quantiles"])]
# bias_2step["Method"]="two-step"
bias_wide = pd.concat([bias_irock,bias_2step])
# bias_wide = bias_wide.reset_index()
replacements={"mRock_kNN_global_linear_Neyman":"i-Rock w. linear quantile",
    "mRock_kNN_global_bs_Neyman":"i-Rock w. B-spline quantile",
                      #"local_adjust":"i-Rock w. local linear quantile (adjusted)",
                      "two_step_Neyman":"two-step",
             "Average of linear quantiles":"quantile average"}
bias_wide["Method"] = bias_wide["Method"].replace(replacements)
bias_long = pd.melt(bias_wide.drop(columns='n'), id_vars=['Method'])
std_irock = std[(std["Method"].isin(methods_to_filter))].drop(columns="num_bin")
std_2step = std_other[std_other["Method"].isin(["two_step_Neyman","Average of linear quantiles"])]
std_wide = pd.concat([std_irock,std_2step])
std_wide["Method"] = std_wide["Method"].replace(replacements)
std_long = pd.melt(std_wide.drop(columns='n'), id_vars=['Method'])
bias_std = bias_long
bias_std["value"] = bias_long["value"]/std_long["value"]
replacements={"beta0":r"$\beta_0$",
             "beta1":r"$\beta_1$",
             "beta2":r"$\beta_2$"}
bias_std["variable"] = bias_std["variable"].replace(replacements)
RMSE_irock = RMSE[(RMSE["Method"].isin(methods_to_filter))].drop(columns="num_bin")
RMSE_2step = RMSE_other[(RMSE_other["Method"]=="two_step_Neyman")].drop(columns=["Method","n"]).reset_index(drop=True)
RMSE_gl = RMSE_2step/RMSE_irock[RMSE_irock["Method"]=="mRock_kNN_global_linear_Neyman"].drop(columns=["Method","n"]).reset_index(drop=True)
RMSE_gl["Method"]="i-Rock w. linear quantile"
#RMSE_gl_ad = RMSE_2step/RMSE_irock[RMSE_irock["Method"]=="global_linear_adjust"].drop(columns=["Method","n"]).reset_index(drop=True)
#RMSE_gl_ad["Method"]="i-Rock w. linear quantile (adjusted)"
#RMSE_lc = RMSE_2step/RMSE_irock[RMSE_irock["Method"]=="local_adjust"].drop(columns=["Method","n"]).reset_index(drop=True)
#RMSE_lc["Method"]="i-Rock w. local linear quantile (adjusted)"
RMSE_bs = RMSE_2step/RMSE_irock[RMSE_irock["Method"]=="mRock_kNN_global_bs_Neyman"].drop(columns=["Method","n"]).reset_index(drop=True)
RMSE_bs["Method"]="i-Rock w. B-spline quantile"
RMSE_mean_quantile = RMSE_2step/RMSE_other[(RMSE_other["Method"]=="Average of linear quantiles")].drop(columns=["Method","n"]).reset_index(drop=True)
RMSE_mean_quantile["Method"]="quantile average"
RMSE_wide = pd.concat([RMSE_gl,RMSE_bs,RMSE_mean_quantile])
RMSE_long = pd.melt(RMSE_wide, id_vars=['Method'])
replacements={"beta0":r"$\beta_0$",
             "beta1":r"$\beta_1$",
             "beta2":r"$\beta_2$"}
RMSE_long["variable"] = RMSE_long["variable"].replace(replacements)

# %%
fig = plt.figure(figsize=(9, 4))
ax = fig.add_subplot(1,2,1)
custom_colors = {
    'i-Rock w. linear quantile': (0.21568627450980393, 0.49411764705882355, 0.7215686274509804),   
    'i-Rock w. B-spline quantile': (1.0, 0.4980392156862745, 0.0),  
    'two-step': (0.30196078431372547, 0.6862745098039216, 0.2901960784313726),
    'quantile average': 'k'
}
custom_order = ['i-Rock w. linear quantile', 'i-Rock w. B-spline quantile','quantile average','two-step']
sns.barplot(data=bias_std, x='variable', y='value', hue='Method', palette=custom_colors, hue_order=custom_order)
# Add labels
plt.xlabel('Coefficients')
plt.ylabel('Relative bias')
#plt.legend()#title='Method')
#ax.legend_.remove()

ax = fig.add_subplot(1,2,2)
custom_colors = {
    'i-Rock w. linear quantile': (0.21568627450980393, 0.49411764705882355, 0.7215686274509804),   
    'i-Rock w. B-spline quantile': (1.0, 0.4980392156862745, 0.0),
    'quantile average': 'k'
}
custom_order = ['i-Rock w. linear quantile', 'i-Rock w. B-spline quantile','quantile average']
sns.barplot(data=RMSE_long, x='variable', y='value', hue='Method',palette=custom_colors, hue_order=custom_order)
# Set y-axis limits
#plt.ylim(0, 2)
ax.axhline(y=1, color=(0.30196078431372547, 0.6862745098039216, 0.2901960784313726), linestyle='--',label='two-step')
# Add labels and a legend
plt.xlabel('Coefficients')
plt.ylabel('RMSE ratio')
handles, labels = ax.get_legend_handles_labels()
new_order = [1, 2, 3, 0]  # Assuming 'two-step' is the second entry
ax.legend([handles[i] for i in new_order], [labels[i] for i in new_order], title='Method')
fig.tight_layout()
plt.savefig("2dim_nl_4methods_n10000_tau9.pdf", format="pdf")

# %%
methods_to_filter = ["mRock_kNN_global_linear_Neyman","mRock_kNN_global_bs_Neyman"]
bias_irock = bias[(bias["Method"].isin(methods_to_filter))].drop(columns="num_bin")#.set_index(['n','Method'])
bias_2step = bias_other[bias_other["Method"]=="two_step_Neyman"]
# bias_2step["Method"]="two-step"
bias_wide = pd.concat([bias_irock,bias_2step])
# bias_wide = bias_wide.reset_index()
replacements={"mRock_kNN_global_linear_Neyman":"i-Rock w. linear quantile",
    "mRock_kNN_global_bs_Neyman":"i-Rock w. B-spline quantile",
                      #"local_adjust":"i-Rock w. local linear quantile (adjusted)",
                      "two_step_Neyman":"two-step"}
bias_wide["Method"] = bias_wide["Method"].replace(replacements)
bias_long = pd.melt(bias_wide.drop(columns='n'), id_vars=['Method'])
std_irock = std[(std["Method"].isin(methods_to_filter))].drop(columns="num_bin")
std_2step = std_other[std_other["Method"]=="two_step_Neyman"]
std_wide = pd.concat([std_irock,std_2step])
std_wide["Method"] = std_wide["Method"].replace(replacements)
std_long = pd.melt(std_wide.drop(columns='n'), id_vars=['Method'])
bias_std = bias_long
bias_std["value"] = bias_long["value"]/std_long["value"]
replacements={"beta0":r"$\beta_0$",
             "beta1":r"$\beta_1$",
             "beta2":r"$\beta_2$"}
bias_std["variable"] = bias_std["variable"].replace(replacements)
RMSE_irock = RMSE[(RMSE["Method"].isin(methods_to_filter))].drop(columns="num_bin")
RMSE_2step = RMSE_other[(RMSE_other["Method"]=="two_step_Neyman")].drop(columns=["Method","n"]).reset_index(drop=True)
RMSE_gl = RMSE_2step/RMSE_irock[RMSE_irock["Method"]=="mRock_kNN_global_linear_Neyman"].drop(columns=["Method","n"]).reset_index(drop=True)
RMSE_gl["Method"]="i-Rock w. linear quantile"
#RMSE_gl_ad = RMSE_2step/RMSE_irock[RMSE_irock["Method"]=="global_linear_adjust"].drop(columns=["Method","n"]).reset_index(drop=True)
#RMSE_gl_ad["Method"]="i-Rock w. linear quantile (adjusted)"
#RMSE_lc = RMSE_2step/RMSE_irock[RMSE_irock["Method"]=="local_adjust"].drop(columns=["Method","n"]).reset_index(drop=True)
#RMSE_lc["Method"]="i-Rock w. local linear quantile (adjusted)"
RMSE_bs = RMSE_2step/RMSE_irock[RMSE_irock["Method"]=="mRock_kNN_global_bs_Neyman"].drop(columns=["Method","n"]).reset_index(drop=True)
RMSE_bs["Method"]="i-Rock w. B-spline quantile"
RMSE_wide = pd.concat([RMSE_gl,RMSE_bs])
RMSE_long = pd.melt(RMSE_wide, id_vars=['Method'])
replacements={"beta0":r"$\beta_0$",
             "beta1":r"$\beta_1$",
             "beta2":r"$\beta_2$"}
RMSE_long["variable"] = RMSE_long["variable"].replace(replacements)

# %%
fig = plt.figure(figsize=(9, 4))
ax = fig.add_subplot(1,2,1)
custom_colors = {
    'i-Rock w. linear quantile': (0.21568627450980393, 0.49411764705882355, 0.7215686274509804),   
    'i-Rock w. B-spline quantile': (1.0, 0.4980392156862745, 0.0),  
    'two-step': (0.30196078431372547, 0.6862745098039216, 0.2901960784313726) 
}
custom_order = ['i-Rock w. linear quantile', 'i-Rock w. B-spline quantile','two-step']
sns.barplot(data=bias_std, x='variable', y='value', hue='Method', palette=custom_colors, hue_order=custom_order)
# Add labels
plt.xlabel('Coefficients')
plt.ylabel('Relative bias')
#plt.legend()#title='Method')
#ax.legend_.remove()

ax = fig.add_subplot(1,2,2)
custom_colors = {
    'i-Rock w. linear quantile': (0.21568627450980393, 0.49411764705882355, 0.7215686274509804),   
    'i-Rock w. B-spline quantile': (1.0, 0.4980392156862745, 0.0)
}
custom_order = ['i-Rock w. linear quantile', 'i-Rock w. B-spline quantile']
sns.barplot(data=RMSE_long, x='variable', y='value', hue='Method',palette=custom_colors, hue_order=custom_order)
# Set y-axis limits
#plt.ylim(0, 2)
ax.axhline(y=1, color=(0.30196078431372547, 0.6862745098039216, 0.2901960784313726), linestyle='--',label='two-step')
# Add labels and a legend
plt.xlabel('Coefficients')
plt.ylabel('RMSE ratio')
#ax.legend_.remove()
handles, labels = ax.get_legend_handles_labels()
new_order = [1, 2, 0]  # Assuming 'two-step' is the second entry
ax.legend([handles[i] for i in new_order], [labels[i] for i in new_order], title='Method')
fig.tight_layout()
#plt.savefig("2dim_nl_disjoint.pdf", format="pdf")
# Out:
# /Users/shushuzhang/anaconda3/envs/research/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/shushuzhang/anaconda3/envs/research/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/shushuzhang/anaconda3/envs/research/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/shushuzhang/anaconda3/envs/research/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/shushuzhang/anaconda3/envs/research/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/shushuzhang/anaconda3/envs/research/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
n = 10000
data = pd.read_csv("results/results_2d_nl_disjoint_final.csv")
data = data[(data["tau"]==0.9)&(data["n"]==10000)]
data_global = data[(data["Method"]=="mRock_kNN_global_bs_Neyman")&(data["num_bin"]==7)]
### tau = 0.8
# beta0 = data_global["beta0"]/np.sqrt(2.463485/n)
# beta1 = data_global["beta1"]/np.sqrt(1.3690273/n)
# beta2 = data_global["beta2"]/np.sqrt(7.6330206/n)
### tau = 0.9
beta0 = data_global["beta0"]/np.sqrt(1.3404259/n)
beta1 = data_global["beta1"]/np.sqrt(0.7449119/n)
beta2 = data_global["beta2"]/np.sqrt(4.1532612/n)
###
# beta0 = data_global["beta0"]/np.sqrt(3.878542/n)
# beta1 = data_global["beta1"]/np.sqrt(1.8988038/n)
# beta2 = data_global["beta2"]/np.sqrt(4.4017361/n)
# get the figure object
fig = plt.figure(figsize=(12, 4))

# first subplot
ax1 = fig.add_subplot(1,3,1)
ax1 = pg.qqplot(beta0, dist='norm', confidence=.99)
#sm.qqplot(beta0, line='45', ax=ax1)
ax1.set_title(r'Q-Q Plot for $\hat \beta_0/\sigma_0^*$')

# second subplot
ax2 = fig.add_subplot(1,3,2)
ax2 = pg.qqplot(beta1, dist='norm', confidence=.99)
#sm.qqplot(beta1, line='45', ax=ax2)
ax2.set_title(r'Q-Q Plot for $\hat \beta_1/\sigma_1^*$')

ax3 = fig.add_subplot(1,3,3)
ax3 = pg.qqplot(beta2, dist='norm', confidence=.99)
#sm.qqplot(beta1, line='45', ax=ax2)
ax3.set_title(r'Q-Q Plot for $\hat \beta_2/\sigma_2^*$')


# show the plot
plt.tight_layout()
#plt.savefig("2dim_qqplot.pdf", format="pdf")

# %% [markdown]
# ## 2 dim discrete

# %%
data_quant = pd.read_csv("results/results_2d_discrete_mean_quantile.csv")
data_other = pd.read_csv("results/results_2d_final.csv")
data = pd.concat([data_quant,data_other])

data = data[data["n"]==2000]
data_group = data.drop(columns=["seed","p","tau","time","num_bin"]).groupby(["Method","n"])
bias = data_group.mean().reset_index()
#bias = math.sqrt(n)*data_group.apply(lambda x:(abs(x)).mean())
std = data_group.std().reset_index()
RMSE = np.sqrt(data_group.apply(lambda x: (x**2).mean())).reset_index()

methods_to_filter = ["mRock","Average of linear quantiles","two_step_Neyman"]
replacements={"mRock":"i-Rock",
                      "two_step_Neyman":"two-step",
             "Average of linear quantiles":"quantile average"}
bias_wide = bias[(bias["Method"].isin(methods_to_filter))]
bias_wide["Method"] = bias_wide["Method"].replace(replacements)
bias_long = pd.melt(bias_wide.drop(columns='n'), id_vars=['Method'])
std_wide = std[(std["Method"].isin(methods_to_filter))]
std_wide["Method"] = std_wide["Method"].replace(replacements)
std_long = pd.melt(std_wide.drop(columns='n'), id_vars=['Method'])
bias_std = bias_long
bias_std["value"] = bias_long["value"]/std_long["value"]
replacements={"beta0":r"$\beta_0$",
             "beta1":r"$\beta_1$",
             "beta2":r"$\beta_2$"}
bias_std["variable"] = bias_std["variable"].replace(replacements)

RMSE_irock = RMSE[(RMSE["Method"].isin(methods_to_filter))]
RMSE_2step = RMSE[(RMSE["Method"]=="two_step_Neyman")].drop(columns=["Method","n"]).reset_index(drop=True)
RMSE_gl = RMSE_2step/RMSE_irock[RMSE_irock["Method"]=="mRock"].drop(columns=["Method","n"]).reset_index(drop=True)
RMSE_gl["Method"]="i-Rock"
RMSE_mean_quantile = RMSE_2step/RMSE_irock[(RMSE_irock["Method"]=="Average of linear quantiles")].drop(columns=["Method","n"]).reset_index(drop=True)
RMSE_mean_quantile["Method"]="quantile average"
RMSE_wide = pd.concat([RMSE_gl,RMSE_mean_quantile])
RMSE_long = pd.melt(RMSE_wide, id_vars=['Method'])
replacements={"beta0":r"$\beta_0$",
             "beta1":r"$\beta_1$",
             "beta2":r"$\beta_2$"}
RMSE_long["variable"] = RMSE_long["variable"].replace(replacements)
# Out:
# /var/folders/8n/xk19drhj641294tk95td17mm0000gn/T/ipykernel_44803/1620233025.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bias_wide["Method"] = bias_wide["Method"].replace(replacements)
# /var/folders/8n/xk19drhj641294tk95td17mm0000gn/T/ipykernel_44803/1620233025.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   std_wide["Method"] = std_wide["Method"].replace(replacements)

# %%
fig = plt.figure(figsize=(9, 4))
ax = fig.add_subplot(1,2,1)
custom_colors = {
    'i-Rock': (0.21568627450980393, 0.49411764705882355, 0.7215686274509804),
    'two-step': (0.30196078431372547, 0.6862745098039216, 0.2901960784313726),
    'quantile average': 'k'
}
custom_order = ['i-Rock','quantile average','two-step']
sns.barplot(data=bias_std, x='variable', y='value', hue='Method', palette=custom_colors, hue_order=custom_order)
# Add labels
plt.xlabel('Coefficients')
plt.ylabel('Relative bias')
#plt.legend()#title='Method')
ax.legend_.remove()

ax = fig.add_subplot(1,2,2)
custom_colors = {
    'i-Rock': (0.21568627450980393, 0.49411764705882355, 0.7215686274509804),
    'quantile average': 'k'
}
custom_order = ['i-Rock','quantile average']
sns.barplot(data=RMSE_long, x='variable', y='value', hue='Method',palette=custom_colors, hue_order=custom_order)
# Set y-axis limits
#plt.ylim(0, 2)
ax.axhline(y=1, color=(0.30196078431372547, 0.6862745098039216, 0.2901960784313726), linestyle='--',label='two-step')
# Add labels and a legend
plt.xlabel('Coefficients')
plt.ylabel('RMSE ratio')
ax.legend_.remove()
handles, labels = ax.get_legend_handles_labels()
new_order = [1, 2, 3, 0]  # Assuming 'two-step' is the second entry
#ax.legend([handles[i] for i in new_order], [labels[i] for i in new_order], title='Method')
fig.tight_layout()
plt.savefig("2dim_discrete_2000.pdf", format="pdf")

# %%
y1 = RMSE[RMSE["Method"]=="mRock"]
y2 = RMSE[RMSE["Method"]=="two_step_Neyman"]
table = np.divide(np.array(y2[["beta0","beta1","beta2"]]),np.array(y1[["beta0","beta1","beta2"]]))
table = pd.DataFrame(table,columns=["beta0","beta1","beta2"], index=[1000,2000,5000])
print(round(table,2).to_latex())
# Out:
# \begin{tabular}{lrrr}
# \toprule
#  & beta0 & beta1 & beta2 \\
# \midrule
# 1000 & 7.190000 & 7.180000 & 1.610000 \\
# 2000 & 9.230000 & 7.690000 & 1.500000 \\
# 5000 & 10.410000 & 8.640000 & 1.630000 \\
# \bottomrule
# \end{tabular}

# %%
y1 = RMSE[RMSE["Method"]=="mRock"]
y2 = RMSE[RMSE["Method"]=="Average of linear quantiles"]
table = np.divide(np.array(y2[["beta0","beta1","beta2"]]),np.array(y1[["beta0","beta1","beta2"]]))
table = pd.DataFrame(table,columns=["beta0","beta1","beta2"], index=[1000,2000,5000])
print(round(table,2).to_latex())
# Out:
# \begin{tabular}{lrrr}
# \toprule
#  & beta0 & beta1 & beta2 \\
# \midrule
# 1000 & 1.850000 & 1.590000 & 1.070000 \\
# 2000 & 1.700000 & 1.330000 & 1.090000 \\
# 5000 & 1.190000 & 1.160000 & 1.270000 \\
# \bottomrule
# \end{tabular}

# %%
data_quant = pd.read_csv("results/results_2d_discrete_mean_quantile.csv")
data_other = pd.read_csv("results/results_2d_final.csv")
data = pd.concat([data_quant,data_other])
data_group = data.drop(columns=["seed","p","tau","time","num_bin"]).groupby(["n","Method"])
bias = data_group.mean()
formatted_bias = bias.applymap(lambda x: f"{x:.2f}")
print(formatted_bias.to_latex())
# Out:
# \begin{tabular}{lllll}
# \toprule
#  &  & beta0 & beta1 & beta2 \\
# n & Method &  &  &  \\
# \midrule
# \multirow[t]{4}{*}{1000} & Average of linear quantiles & 0.98 & -0.03 & -2.21 \\
#  & mRock & 0.12 & -0.04 & -1.94 \\
#  & two_step_LS & 0.46 & -0.35 & -0.02 \\
#  & two_step_Neyman & 0.02 & -0.01 & 0.09 \\
# \cline{1-5}
# \multirow[t]{4}{*}{2000} & Average of linear quantiles & 0.41 & -0.09 & -2.21 \\
#  & mRock & 0.10 & -0.07 & -1.27 \\
#  & two_step_LS & 0.26 & -0.29 & -0.23 \\
#  & two_step_Neyman & 0.33 & -0.27 & -0.33 \\
# \cline{1-5}
# \multirow[t]{4}{*}{5000} & Average of linear quantiles & 0.03 & 0.02 & -1.86 \\
#  & mRock & 0.01 & -0.01 & -0.40 \\
#  & two_step_LS & -0.01 & 0.03 & -0.02 \\
#  & two_step_Neyman & -0.13 & 0.16 & -0.04 \\
# \cline{1-5}
# \bottomrule
# \end{tabular}

# %%
data_weighted_2step = pd.read_csv("results/results_2d_discrete_true_weighted_2step.csv")
data_weighted_2step["Method"] = "true weighted two-step"
data_quant = pd.read_csv("results/results_2d_discrete_3step.csv")
data_other = pd.read_csv("results/results_2d_discrete.csv")
data_all = pd.concat([data_weighted_2step,data_quant,data_other])
fig = plt.figure(figsize=(6, 6))
for i, n in zip([1,2,3,4],[1000,2000,5000,10000]):
    ax = fig.add_subplot(2,2,i)
    data = data_all[(data_all["n"]==n)&(data_all["tau"]==0.9)]
    data_group = data.drop(columns=["seed","p","tau","time","num_bin"]).groupby(["Method","n"])
    bias = data_group.mean().reset_index()
    #bias = math.sqrt(n)*data_group.apply(lambda x:(abs(x)).mean())
    std = data_group.std().reset_index()
    RMSE = np.sqrt(data_group.apply(lambda x: (x**2).mean())).reset_index()

    methods_to_filter = ["mRock","three_step","two_step_Neyman","true weighted two-step"]
    replacements={"mRock":"i-Rock",
                          "two_step_Neyman":"two-step",
                 "three_step":"weighted two-step"}
    bias_wide = bias[(bias["Method"].isin(methods_to_filter))]
    bias_wide["Method"] = bias_wide["Method"].replace(replacements)
    bias_long = pd.melt(bias_wide.drop(columns='n'), id_vars=['Method'])
    std_wide = std[(std["Method"].isin(methods_to_filter))]
    std_wide["Method"] = std_wide["Method"].replace(replacements)
    std_long = pd.melt(std_wide.drop(columns='n'), id_vars=['Method'])
    bias_std = bias_long
    bias_std["value"] = bias_long["value"]/std_long["value"]
    replacements={"beta0":r"$\beta_0$",
                 "beta1":r"$\beta_1$",
                 "beta2":r"$\beta_2$"}
    bias_std["variable"] = bias_std["variable"].replace(replacements)

    RMSE_irock = RMSE[(RMSE["Method"].isin(methods_to_filter))]
    RMSE_2step = RMSE[(RMSE["Method"]=="two_step_Neyman")].drop(columns=["Method","n"]).reset_index(drop=True)
    RMSE_gl = RMSE_2step/RMSE_irock[RMSE_irock["Method"]=="mRock"].drop(columns=["Method","n"]).reset_index(drop=True)
    RMSE_gl["Method"]="i-Rock"
    RMSE_mean_quantile = RMSE_2step/RMSE_irock[(RMSE_irock["Method"]=="three_step")].drop(columns=["Method","n"]).reset_index(drop=True)
    RMSE_mean_quantile["Method"]="weighted two-step"
    RMSE_weight_2step = RMSE_2step/RMSE_irock[(RMSE_irock["Method"]=="true weighted two-step")].drop(columns=["Method","n"]).reset_index(drop=True)
    RMSE_weight_2step["Method"]="true weighted two-step"
    RMSE_wide = pd.concat([RMSE_gl,RMSE_mean_quantile,RMSE_weight_2step])
    RMSE_long = pd.melt(RMSE_wide, id_vars=['Method'])
    replacements={"beta0":r"$\beta_0$",
                 "beta1":r"$\beta_1$",
                 "beta2":r"$\beta_2$"}
    RMSE_long["variable"] = RMSE_long["variable"].replace(replacements)
    
#     ax = fig.add_subplot(1,2,1)
#     custom_colors = {
#         'i-Rock': (0.21568627450980393, 0.49411764705882355, 0.7215686274509804),
#         'two-step': (0.30196078431372547, 0.6862745098039216, 0.2901960784313726),
#         'weighted two-step': 'k'
#     }
#     custom_order = ['i-Rock','weighted two-step','two-step']
#     sns.barplot(data=bias_std, x='variable', y='value', hue='Method', palette=custom_colors, hue_order=custom_order)
#     # Add labels
#     plt.xlabel('Coefficients')
#     plt.ylabel('Relative bias')
#     #plt.legend()#title='Method')
#     ax.legend_.remove()

    
    custom_colors = {
        'i-Rock': (0.21568627450980393, 0.49411764705882355, 0.7215686274509804),
        'weighted two-step': 'k',
        "true weighted two-step": 'r',
    }
    custom_order = ['i-Rock','weighted two-step',"true weighted two-step"]
    sns.barplot(data=RMSE_long, x='variable', y='value', hue='Method',palette=custom_colors, hue_order=custom_order)
    # Set y-axis limits
    #plt.ylim(0, 2)
    ax.axhline(y=1, color=(0.30196078431372547, 0.6862745098039216, 0.2901960784313726), linestyle='--',label='two-step')
    # Add labels and a legend
    plt.xlabel('Coefficients')
    plt.ylabel('RMSE ratio')
    plt.title(f'n={n}')
    ax.legend_.remove()
    handles, labels = ax.get_legend_handles_labels()
    new_order = [1, 2, 3, 4, 0]  # Assuming 'two-step' is the second entry
    #ax.legend([handles[i] for i in new_order], [labels[i] for i in new_order], title='Method')
    fig.tight_layout()
plt.savefig("2dim_discrete_weighted.pdf", format="pdf")
# Out:
# /var/folders/8n/xk19drhj641294tk95td17mm0000gn/T/ipykernel_58594/3116015561.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bias_wide["Method"] = bias_wide["Method"].replace(replacements)
# /var/folders/8n/xk19drhj641294tk95td17mm0000gn/T/ipykernel_58594/3116015561.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   std_wide["Method"] = std_wide["Method"].replace(replacements)
# /var/folders/8n/xk19drhj641294tk95td17mm0000gn/T/ipykernel_58594/3116015561.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bias_wide["Method"] = bias_wide["Method"].replace(replacements)
# /var/folders/8n/xk19drhj641294tk95td17mm0000gn/T/ipykernel_58594/3116015561.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   std_wide["Method"] = std_wide["Method"].replace(replacements)
# /var/folders/8n/xk19drhj641294tk95td17mm0000gn/T/ipykernel_58594/3116015561.py:81: UserWarning: The figure layout has changed to tight
#   fig.tight_layout()
# /var/folders/8n/xk19drhj641294tk95td17mm0000gn/T/ipykernel_58594/3116015561.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bias_wide["Method"] = bias_wide["Method"].replace(replacements)
# /var/folders/8n/xk19drhj641294tk95td17mm0000gn/T/ipykernel_58594/3116015561.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   std_wide["Method"] = std_wide["Method"].replace(replacements)
# /var/folders/8n/xk19drhj641294tk95td17mm0000gn/T/ipykernel_58594/3116015561.py:81: UserWarning: The figure layout has changed to tight
#   fig.tight_layout()
# /var/folders/8n/xk19drhj641294tk95td17mm0000gn/T/ipykernel_58594/3116015561.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bias_wide["Method"] = bias_wide["Method"].replace(replacements)
# /var/folders/8n/xk19drhj641294tk95td17mm0000gn/T/ipykernel_58594/3116015561.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   std_wide["Method"] = std_wide["Method"].replace(replacements)
# /var/folders/8n/xk19drhj641294tk95td17mm0000gn/T/ipykernel_58594/3116015561.py:81: UserWarning: The figure layout has changed to tight
#   fig.tight_layout()

# %%
RMSE
# Out:
#                    Method      n     beta0     beta1     beta2
# 0                   mRock  10000  0.262106  0.248159  1.696586
# 1            mRock_global  10000  1.427669  1.264273  1.929953
# 2              three_step  10000  0.243862  0.236146  1.684017
# 3  true weighted two-step  10000  0.157280  0.130779  1.578022
# 4             two_step_LS  10000  2.030027  1.682413  2.290361
# 5         two_step_Neyman  10000  2.822356  2.313423  2.662443

# %%
y1 = RMSE[RMSE["Method"]=="three_step"]
y2 = RMSE[RMSE["Method"]=="two_step_Neyman"]
table = np.divide(np.array(y2[["beta0","beta1","beta2"]]),np.array(y1[["beta0","beta1","beta2"]]))
table = pd.DataFrame(table,columns=["beta0","beta1","beta2"], index=[1000,2000,5000])
print(round(table,2).to_latex())

# %% [markdown]
# ## 2dim: 1 continuous + 1 discrete

# %%
data_mean_quant = pd.read_csv("results/results_2d_mean_quantile.csv")
data_others = pd.read_csv("results/results_2d_disjoint_final.csv")
data = pd.concat([data_mean_quant,data_others])
#data = pd.read_csv("results_2d_disjoint_final.csv")
data = data[(data["n"]==5000)&(data["tau"]==0.8)]
num_bin = 6
# data = pd.read_csv("results_2d_disjoint2.csv")
# data = data[(data["n"]==10000)&(data["tau"]==0.8)]
# kNN
#data_group = data.drop(columns=["seed","p","time"]).groupby(["n","tau","Method","num_bin"])
data_group = data.drop(columns=["seed","p","time","tau"]).groupby(["Method","n","num_bin"])
bias = data_group.mean().reset_index()
std = data_group.std().reset_index()
RMSE = np.sqrt(data_group.apply(lambda x: (x**2).mean())).reset_index()
data_group_other = data[np.isnan(data["num_bin"])].drop(columns=["seed","p","tau","time","num_bin"]).groupby(["Method","n"])
bias_other = data_group_other.mean().reset_index()
std_other = data_group_other.std().reset_index()
RMSE_other = np.sqrt(data_group_other.apply(lambda x: (x**2).mean())).reset_index()

bias = bias[bias["num_bin"]==num_bin]
std = std[std["num_bin"]==num_bin]
RMSE = RMSE[RMSE["num_bin"]==num_bin]
methods_to_filter = ["mRock_kNN_global_linear_Neyman","mRock_kNN_bs_Neyman"]
bias_irock = bias[(bias["Method"].isin(methods_to_filter))].drop(columns="num_bin")#.set_index(['n','Method'])
bias_2step = bias_other[bias_other["Method"].isin(["two_step_Neyman","Average of linear quantiles"])]
# bias_2step["Method"]="two-step"
bias_wide = pd.concat([bias_irock,bias_2step])
# bias_wide = bias_wide.reset_index()
replacements={"mRock_kNN_global_linear_Neyman":"i-Rock w. linear quantile",
    "mRock_kNN_bs_Neyman":"i-Rock w. B-spline quantile",
                      #"local_adjust":"i-Rock w. local linear quantile (adjusted)",
                      "two_step_Neyman":"two-step",
             "Average of linear quantiles":"quantile average"}
bias_wide["Method"] = bias_wide["Method"].replace(replacements)
bias_long = pd.melt(bias_wide.drop(columns='n'), id_vars=['Method'])
std_irock = std[(std["Method"].isin(methods_to_filter))].drop(columns="num_bin")
std_2step = std_other[std_other["Method"].isin(["two_step_Neyman","Average of linear quantiles"])]
std_wide = pd.concat([std_irock,std_2step])
std_wide["Method"] = std_wide["Method"].replace(replacements)
std_long = pd.melt(std_wide.drop(columns='n'), id_vars=['Method'])
bias_std = bias_long
bias_std["value"] = bias_long["value"]/std_long["value"]
replacements={"beta0":r"$\beta_0$",
             "beta1":r"$\beta_1$",
             "beta2":r"$\beta_2$"}
bias_std["variable"] = bias_std["variable"].replace(replacements)
RMSE_irock = RMSE[(RMSE["Method"].isin(methods_to_filter))].drop(columns="num_bin")
RMSE_2step = RMSE_other[(RMSE_other["Method"]=="two_step_Neyman")].drop(columns=["Method","n"]).reset_index(drop=True)
RMSE_gl = RMSE_2step/RMSE_irock[RMSE_irock["Method"]=="mRock_kNN_global_linear_Neyman"].drop(columns=["Method","n"]).reset_index(drop=True)
RMSE_gl["Method"]="i-Rock w. linear quantile"
#RMSE_gl_ad = RMSE_2step/RMSE_irock[RMSE_irock["Method"]=="global_linear_adjust"].drop(columns=["Method","n"]).reset_index(drop=True)
#RMSE_gl_ad["Method"]="i-Rock w. linear quantile (adjusted)"
#RMSE_lc = RMSE_2step/RMSE_irock[RMSE_irock["Method"]=="local_adjust"].drop(columns=["Method","n"]).reset_index(drop=True)
#RMSE_lc["Method"]="i-Rock w. local linear quantile (adjusted)"
RMSE_bs = RMSE_2step/RMSE_irock[RMSE_irock["Method"]=="mRock_kNN_bs_Neyman"].drop(columns=["Method","n"]).reset_index(drop=True)
RMSE_bs["Method"]="i-Rock w. B-spline quantile"
RMSE_mean_quantile = RMSE_2step/RMSE_other[(RMSE_other["Method"]=="Average of linear quantiles")].drop(columns=["Method","n"]).reset_index(drop=True)
RMSE_mean_quantile["Method"]="quantile average"
RMSE_wide = pd.concat([RMSE_gl,RMSE_bs,RMSE_mean_quantile])
RMSE_long = pd.melt(RMSE_wide, id_vars=['Method'])
replacements={"beta0":r"$\beta_0$",
             "beta1":r"$\beta_1$",
             "beta2":r"$\beta_2$"}
RMSE_long["variable"] = RMSE_long["variable"].replace(replacements)

# %%
fig = plt.figure(figsize=(9, 4))
ax = fig.add_subplot(1,2,1)
custom_colors = {
    'i-Rock w. linear quantile': (0.21568627450980393, 0.49411764705882355, 0.7215686274509804),   
    'i-Rock w. B-spline quantile': (1.0, 0.4980392156862745, 0.0),  
    'two-step': (0.30196078431372547, 0.6862745098039216, 0.2901960784313726),
    'quantile average': 'k'
}
custom_order = ['i-Rock w. linear quantile', 'i-Rock w. B-spline quantile','quantile average','two-step']
sns.barplot(data=bias_std, x='variable', y='value', hue='Method', palette=custom_colors, hue_order=custom_order)
# Add labels
plt.xlabel('Coefficients')
plt.ylabel('Relative bias')
#plt.legend()#title='Method')
ax.legend_.remove()

ax = fig.add_subplot(1,2,2)
custom_colors = {
    'i-Rock w. linear quantile': (0.21568627450980393, 0.49411764705882355, 0.7215686274509804),   
    'i-Rock w. B-spline quantile': (1.0, 0.4980392156862745, 0.0),
    'quantile average': 'k'
}
custom_order = ['i-Rock w. linear quantile', 'i-Rock w. B-spline quantile','quantile average']
sns.barplot(data=RMSE_long, x='variable', y='value', hue='Method',palette=custom_colors, hue_order=custom_order)
# Set y-axis limits
#plt.ylim(0, 2)
ax.axhline(y=1, color=(0.30196078431372547, 0.6862745098039216, 0.2901960784313726), linestyle='--',label='two-step')
# Add labels and a legend
plt.xlabel('Coefficients')
plt.ylabel('RMSE ratio')
ax.legend_.remove()
#plt.legend(title='Method',bbox_to_anchor = (1, 0.5))
#handles, labels = ax.get_legend_handles_labels()
#new_order = [1, 2, 0]  # Assuming 'two-step' is the second entry
#ax.legend([handles[i] for i in new_order], [labels[i] for i in new_order])#, title='Method')#, bbox_to_anchor=(1, 0.5))
#ax.legend(title='Method', bbox_to_anchor=(1, 0.5))
fig.tight_layout()
#plt.savefig("2dim_4methods_n5000_tau8.pdf", format="pdf")

# %%
data_weighted_2step = pd.read_csv("results/results_2d_true_weighted_2step.csv")
data_weighted_2step["Method"] = "true weighted two-step"
data_mean_quant = pd.read_csv("results/results_2d_3step.csv")
data_others = pd.read_csv("results/results_2d_disjoint_final.csv")
data_all = pd.concat([data_mean_quant,data_others,data_weighted_2step])
#data = pd.read_csv("results_2d_disjoint_final.csv")
for n in [5000,10000]:
    for tau in [0.8,0.9]:
        data = data_all[(data_all["n"]==n)&(data_all["tau"]==tau)]
        num_bin = 6
        data_group = data.drop(columns=["seed","p","time","tau"]).groupby(["Method","n","num_bin"])
        bias = data_group.mean().reset_index()
        std = data_group.std().reset_index()
        RMSE = np.sqrt(data_group.apply(lambda x: (x**2).mean())).reset_index()
        data_group_other = data[np.isnan(data["num_bin"])].drop(columns=["seed","p","tau","time","num_bin"]).groupby(["Method","n"])
        bias_other = data_group_other.mean().reset_index()
        std_other = data_group_other.std().reset_index()
        RMSE_other = np.sqrt(data_group_other.apply(lambda x: (x**2).mean())).reset_index()

        bias = bias[bias["num_bin"]==num_bin]
        std = std[std["num_bin"]==num_bin]
        RMSE = RMSE[RMSE["num_bin"]==num_bin]
        methods_to_filter = ["mRock_kNN_global_linear_Neyman","mRock_kNN_bs_Neyman"]
        bias_irock = bias[(bias["Method"].isin(methods_to_filter))].drop(columns="num_bin")#.set_index(['n','Method'])
        bias_2step = bias_other[bias_other["Method"].isin(["two_step_Neyman","three_step","true weighted two-step"])]
        # bias_2step["Method"]="two-step"
        bias_wide = pd.concat([bias_irock,bias_2step])
        # bias_wide = bias_wide.reset_index()
        replacements={"mRock_kNN_global_linear_Neyman":"i-Rock w. linear quantile",
            "mRock_kNN_bs_Neyman":"i-Rock w. B-spline quantile",
                              #"local_adjust":"i-Rock w. local linear quantile (adjusted)",
                              "two_step_Neyman":"two-step",
                     "three_step":"weighted two-step"}
        bias_wide["Method"] = bias_wide["Method"].replace(replacements)
        bias_long = pd.melt(bias_wide.drop(columns='n'), id_vars=['Method'])
        std_irock = std[(std["Method"].isin(methods_to_filter))].drop(columns="num_bin")
        std_2step = std_other[std_other["Method"].isin(["two_step_Neyman","three_step","true weighted two-step"])]
        std_wide = pd.concat([std_irock,std_2step])
        std_wide["Method"] = std_wide["Method"].replace(replacements)
        std_long = pd.melt(std_wide.drop(columns='n'), id_vars=['Method'])
        bias_std = bias_long
        bias_std["value"] = bias_long["value"]/std_long["value"]
        replacements={"beta0":r"$\beta_0$",
                     "beta1":r"$\beta_1$",
                     "beta2":r"$\beta_2$"}
        bias_std["variable"] = bias_std["variable"].replace(replacements)
        RMSE_irock = RMSE[(RMSE["Method"].isin(methods_to_filter))].drop(columns="num_bin")
        RMSE_2step = RMSE_other[(RMSE_other["Method"]=="two_step_Neyman")].drop(columns=["Method","n"]).reset_index(drop=True)
        RMSE_gl = RMSE_2step/RMSE_irock[RMSE_irock["Method"]=="mRock_kNN_global_linear_Neyman"].drop(columns=["Method","n"]).reset_index(drop=True)
        RMSE_gl["Method"]="i-Rock w. linear quantile"
        #RMSE_gl_ad = RMSE_2step/RMSE_irock[RMSE_irock["Method"]=="global_linear_adjust"].drop(columns=["Method","n"]).reset_index(drop=True)
        #RMSE_gl_ad["Method"]="i-Rock w. linear quantile (adjusted)"
        #RMSE_lc = RMSE_2step/RMSE_irock[RMSE_irock["Method"]=="local_adjust"].drop(columns=["Method","n"]).reset_index(drop=True)
        #RMSE_lc["Method"]="i-Rock w. local linear quantile (adjusted)"
        RMSE_bs = RMSE_2step/RMSE_irock[RMSE_irock["Method"]=="mRock_kNN_bs_Neyman"].drop(columns=["Method","n"]).reset_index(drop=True)
        RMSE_bs["Method"]="i-Rock w. B-spline quantile"
        RMSE_mean_quantile = RMSE_2step/RMSE_other[(RMSE_other["Method"]=="three_step")].drop(columns=["Method","n"]).reset_index(drop=True)
        RMSE_mean_quantile["Method"]="weighted two-step"
        RMSE_weight_2step = RMSE_2step/RMSE_other[(RMSE_other["Method"]=="true weighted two-step")].drop(columns=["Method","n"]).reset_index(drop=True)
        RMSE_weight_2step["Method"]="true weighted two-step"
        RMSE_wide = pd.concat([RMSE_gl,RMSE_bs,RMSE_mean_quantile,RMSE_weight_2step])
        RMSE_long = pd.melt(RMSE_wide, id_vars=['Method'])
        replacements={"beta0":r"$\beta_0$",
                     "beta1":r"$\beta_1$",
                     "beta2":r"$\beta_2$"}
        RMSE_long["variable"] = RMSE_long["variable"].replace(replacements)
        fig = plt.figure(figsize=(4, 4))
#         ax = fig.add_subplot(1,2,1)
#         custom_colors = {
#             'i-Rock w. linear quantile': (0.21568627450980393, 0.49411764705882355, 0.7215686274509804),   
#             'i-Rock w. B-spline quantile': (1.0, 0.4980392156862745, 0.0),  
#             'two-step': (0.30196078431372547, 0.6862745098039216, 0.2901960784313726),
#             'weighted two-step': (0,0,0),
#             'true weighted two-step': 'r'
#         }
#         custom_order = ['i-Rock w. linear quantile', 'i-Rock w. B-spline quantile','two-step','weighted two-step','true weighted two-step']
#         sns.barplot(data=bias_std, x='variable', y='value', hue='Method', palette=custom_colors, hue_order=custom_order)
#         # Add labels and a legend
#         plt.xlabel('Coefficients')
#         plt.ylabel('Relative bias')
#         # plt.legend(title='Method',loc="upper right")
#         ax.legend_.remove()

        ax = fig.add_subplot(1,1,1)
        custom_colors = {
            'i-Rock w. linear quantile': (0.21568627450980393, 0.49411764705882355, 0.7215686274509804),   
            'i-Rock w. B-spline quantile': (1.0, 0.4980392156862745, 0.0),
            'weighted two-step': (0,0,0),
            'true weighted two-step': 'r'
        }
        custom_order = ['i-Rock w. linear quantile', 'i-Rock w. B-spline quantile', 'weighted two-step','true weighted two-step']
        sns.barplot(data=RMSE_long, x='variable', y='value', hue='Method',palette=custom_colors, hue_order=custom_order)
        ax.axhline(y=1, color=(0.30196078431372547, 0.6862745098039216, 0.2901960784313726), linestyle='--',label='two-step')
        # Add labels and a legend
        plt.xlabel('Coefficients')
        plt.ylabel('RMSE ratio')
        #plt.legend(title='Method',bbox_to_anchor = (1, 0.5))
        handles, labels = ax.get_legend_handles_labels()
        new_order = [1, 2, 3, 4, 0]  # Assuming 'two-step' is the second entry
        ax.legend_.remove()
        # ax.legend([handles[i] for i in new_order], [labels[i] for i in new_order], title='Method', bbox_to_anchor=(1, 0.5))
        #ax.legend(title='Method', bbox_to_anchor=(1, 0.5))
        fig.tight_layout()
        plt.savefig(f"2dim_disjoint_weighted_n{n}_tau{int(10*tau)}.pdf", format="pdf")

# %%
data_others = pd.read_csv("results/results_2d_disjoint_final.csv")
# Out:
#                                Method  tau      n  p  seed  num_bin     beta0  \
# 0                 mRock_kNN_bs_Neyman  0.8  10000  2     1      2.0  0.018102
# 1      mRock_kNN_global_linear_Neyman  0.8  10000  2     1      2.0  0.013738
# 2                 mRock_kNN_bs_Neyman  0.8  10000  2     1      3.0  0.011225
# 3      mRock_kNN_global_linear_Neyman  0.8  10000  2     1      3.0  0.007330
# 4                 mRock_kNN_bs_Neyman  0.8  10000  2     1      4.0 -0.003958
# ...                               ...  ...    ... ..   ...      ...       ...
# 71995  mRock_kNN_global_linear_Neyman  0.9   5000  2    99      8.0  0.011771
# 71996             mRock_kNN_bs_Neyman  0.9   5000  2    99      9.0  0.015355
# 71997  mRock_kNN_global_linear_Neyman  0.9   5000  2    99      9.0  0.015743
# 71998                 two_step_Neyman  0.9   5000  2    99      NaN  0.017162
# 71999                     two_step_LS  0.9   5000  2    99      NaN  0.016615
#
#           beta1     beta2     time
# 0     -0.009660 -0.032207  117.135
# 1     -0.007669 -0.028129  103.743
# 2     -0.010044 -0.018916  117.259
# 3     -0.007905 -0.015388  102.837
# 4      0.000833 -0.027495  117.144
# ...         ...       ...      ...
# 71995 -0.000789 -0.047567   13.231
# 71996 -0.000413 -0.048800   15.127
# 71997 -0.000002 -0.049057   13.244
# 71998 -0.005241 -0.049377    0.031
# 71999 -0.005521 -0.047500    0.010
#
# [72000 rows x 10 columns]

# %%
data_weighted_2step = pd.read_csv("results/results_2d_true_weighted_2step.csv")
data_weighted_2step["Method"] = "true weighted two-step"
data_mean_quant = pd.read_csv("results/results_2d_3step.csv")
data_others = pd.read_csv("results/results_2d_disjoint_final.csv")
data_all = pd.concat([data_mean_quant,data_others,data_weighted_2step])
data_all["beta0"] = (data_all["beta0"] + 1.95 + 2*(data_all["beta1"] + 3.9) + 0.5*(data_all["beta1"] + 5.85))-6.5*1.95
#data = pd.read_csv("results_2d_disjoint_final.csv")
for n in [5000,10000]:
    for tau in [0.8,0.9]:
        data = data_all[(data_all["n"]==n)&(data_all["tau"]==tau)]
        num_bin = 6
        data_group = data.drop(columns=["seed","p","time","tau"]).groupby(["Method","n","num_bin"])
        bias = data_group.mean().reset_index()
        std = data_group.std().reset_index()
        RMSE = np.sqrt(data_group.apply(lambda x: (x**2).mean())).reset_index()
        data_group_other = data[np.isnan(data["num_bin"])].drop(columns=["seed","p","tau","time","num_bin"]).groupby(["Method","n"])
        bias_other = data_group_other.mean().reset_index()
        std_other = data_group_other.std().reset_index()
        RMSE_other = np.sqrt(data_group_other.apply(lambda x: (x**2).mean())).reset_index()

        bias = bias[bias["num_bin"]==num_bin]
        std = std[std["num_bin"]==num_bin]
        RMSE = RMSE[RMSE["num_bin"]==num_bin]
        methods_to_filter = ["mRock_kNN_global_linear_Neyman","mRock_kNN_bs_Neyman"]
        bias_irock = bias[(bias["Method"].isin(methods_to_filter))].drop(columns="num_bin")#.set_index(['n','Method'])
        bias_2step = bias_other[bias_other["Method"].isin(["two_step_Neyman","three_step","true weighted two-step"])]
        # bias_2step["Method"]="two-step"
        bias_wide = pd.concat([bias_irock,bias_2step])
        # bias_wide = bias_wide.reset_index()
        replacements={"mRock_kNN_global_linear_Neyman":"i-Rock w. linear quantile",
            "mRock_kNN_bs_Neyman":"i-Rock w. B-spline quantile",
                              #"local_adjust":"i-Rock w. local linear quantile (adjusted)",
                              "two_step_Neyman":"two-step",
                     "three_step":"weighted two-step"}
        bias_wide["Method"] = bias_wide["Method"].replace(replacements)
        bias_long = pd.melt(bias_wide.drop(columns='n'), id_vars=['Method'])
        std_irock = std[(std["Method"].isin(methods_to_filter))].drop(columns="num_bin")
        std_2step = std_other[std_other["Method"].isin(["two_step_Neyman","three_step","true weighted two-step"])]
        std_wide = pd.concat([std_irock,std_2step])
        std_wide["Method"] = std_wide["Method"].replace(replacements)
        std_long = pd.melt(std_wide.drop(columns='n'), id_vars=['Method'])
        bias_std = bias_long
        bias_std["value"] = bias_long["value"]/std_long["value"]
        replacements={"beta0":r"$\beta_0$",
                     "beta1":r"$\beta_1$",
                     "beta2":r"$\beta_2$"}
        bias_std["variable"] = bias_std["variable"].replace(replacements)
        RMSE_irock = RMSE[(RMSE["Method"].isin(methods_to_filter))].drop(columns="num_bin")
        RMSE_2step = RMSE_other[(RMSE_other["Method"]=="two_step_Neyman")].drop(columns=["Method","n"]).reset_index(drop=True)
        RMSE_gl = RMSE_2step/RMSE_irock[RMSE_irock["Method"]=="mRock_kNN_global_linear_Neyman"].drop(columns=["Method","n"]).reset_index(drop=True)
        RMSE_gl["Method"]="i-Rock w. linear quantile"
        #RMSE_gl_ad = RMSE_2step/RMSE_irock[RMSE_irock["Method"]=="global_linear_adjust"].drop(columns=["Method","n"]).reset_index(drop=True)
        #RMSE_gl_ad["Method"]="i-Rock w. linear quantile (adjusted)"
        #RMSE_lc = RMSE_2step/RMSE_irock[RMSE_irock["Method"]=="local_adjust"].drop(columns=["Method","n"]).reset_index(drop=True)
        #RMSE_lc["Method"]="i-Rock w. local linear quantile (adjusted)"
        RMSE_bs = RMSE_2step/RMSE_irock[RMSE_irock["Method"]=="mRock_kNN_bs_Neyman"].drop(columns=["Method","n"]).reset_index(drop=True)
        RMSE_bs["Method"]="i-Rock w. B-spline quantile"
        RMSE_mean_quantile = RMSE_2step/RMSE_other[(RMSE_other["Method"]=="three_step")].drop(columns=["Method","n"]).reset_index(drop=True)
        RMSE_mean_quantile["Method"]="weighted two-step"
        RMSE_weight_2step = RMSE_2step/RMSE_other[(RMSE_other["Method"]=="true weighted two-step")].drop(columns=["Method","n"]).reset_index(drop=True)
        RMSE_weight_2step["Method"]="true weighted two-step"
        RMSE_wide = pd.concat([RMSE_gl,RMSE_bs,RMSE_mean_quantile,RMSE_weight_2step])
        RMSE_long = pd.melt(RMSE_wide, id_vars=['Method'])
        replacements={"beta0":r"$\beta_0$",
                     "beta1":r"$\beta_1$",
                     "beta2":r"$\beta_2$"}
        RMSE_long["variable"] = RMSE_long["variable"].replace(replacements)
        fig = plt.figure(figsize=(6, 3))
        ax = fig.add_subplot(1,2,1)
        custom_colors = {
            'i-Rock w. linear quantile': (0.21568627450980393, 0.49411764705882355, 0.7215686274509804),   
            'i-Rock w. B-spline quantile': (1.0, 0.4980392156862745, 0.0),  
            'two-step': (0.30196078431372547, 0.6862745098039216, 0.2901960784313726),
            'weighted two-step': (0,0,0),
            'true weighted two-step': 'r'
        }
        custom_order = ['i-Rock w. linear quantile', 'i-Rock w. B-spline quantile','two-step','weighted two-step','true weighted two-step']
        sns.barplot(data=bias_std, x='variable', y='value', hue='Method', palette=custom_colors, hue_order=custom_order)
        # Add labels and a legend
        plt.xlabel('Coefficients')
        plt.ylabel('Relative bias')
        # plt.legend(title='Method',loc="upper right")
        ax.legend_.remove()

        ax = fig.add_subplot(1,2,2)
        custom_colors = {
            'i-Rock w. linear quantile': (0.21568627450980393, 0.49411764705882355, 0.7215686274509804),   
            'i-Rock w. B-spline quantile': (1.0, 0.4980392156862745, 0.0),
            'weighted two-step': (0,0,0),
            'true weighted two-step': 'r'
        }
        custom_order = ['i-Rock w. linear quantile', 'i-Rock w. B-spline quantile', 'weighted two-step','true weighted two-step']
        sns.barplot(data=RMSE_long, x='variable', y='value', hue='Method',palette=custom_colors, hue_order=custom_order)
        ax.axhline(y=1, color=(0.30196078431372547, 0.6862745098039216, 0.2901960784313726), linestyle='--',label='two-step')
        # Add labels and a legend
        plt.xlabel('Coefficients')
        plt.ylabel('RMSE ratio')
        #plt.legend(title='Method',bbox_to_anchor = (1, 0.5))
        handles, labels = ax.get_legend_handles_labels()
        new_order = [1, 2, 3, 4, 0]  # Assuming 'two-step' is the second entry
        ax.legend_.remove()
        # ax.legend([handles[i] for i in new_order], [labels[i] for i in new_order], title='Method', bbox_to_anchor=(1, 0.5))
        #ax.legend(title='Method', bbox_to_anchor=(1, 0.5))
        fig.tight_layout()
        plt.savefig(f"2dim_disjoint_centered_weighted_n{n}_tau{int(10*tau)}.pdf", format="pdf")

# %%
RMSE
# Out:
#                             Method      n  num_bin     beta0     beta1  \
# 4              mRock_kNN_bs_Neyman  10000      6.0  0.016154  0.008983
# 12  mRock_kNN_global_linear_Neyman  10000      6.0  0.016245  0.009086
#
#        beta2
# 4   0.021017
# 12  0.020967

# %%
RMSE_other
# Out:
#                    Method      n     beta0     beta1     beta2
# 0              three_step  10000  0.016076  0.008281  0.021142
# 1  true weighted two-step  10000  0.015663  0.007620  0.019055
# 2             two_step_LS  10000  0.016380  0.009530  0.022378
# 3         two_step_Neyman  10000  0.016844  0.011649  0.026188

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# Sample data for legend
categories = ['i-Rock w. linear quantile', 'i-Rock w. B-spline quantile', 'two-step']
colors = [(0.21568627450980393, 0.49411764705882355, 0.7215686274509804), (1.0, 0.4980392156862745, 0.0), (0.30196078431372547, 0.6862745098039216, 0.2901960784313726)]

# Create a figure
fig = plt.figure(figsize=(9, 0.5))
ax = fig.add_subplot(1, 1, 1)

# Create legend handles
handles = [mpatches.Patch(color=color, label=category) for color, category in zip(colors, categories)]

# Add an invisible handle for the title
title_handle = mpatches.Patch(color='none', label='Method')

# Add the legend to the plot
legend = ax.legend(
    handles=[title_handle] + handles,
    loc='center', 
    bbox_to_anchor=(0.5, 0.5), 
    ncol=len(categories) + 1,
    handletextpad=1.5, 
    borderaxespad=0
)

# Customize the legend title
legend.get_texts()[0].set_fontsize('large')
legend.get_texts()[0].set_fontweight('bold')
#legend.get_texts()[0].set_color('red')

# Remove the axes
ax.axis('off')

# Save the plot
plt.savefig("legend.pdf", format="pdf")

# Show the plot (optional)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# Sample data for legend
categories = [
    'i-Rock w. linear quantile',
    'i-Rock w. B-spline quantile',
    'weighted two-step',
    'two-step w. true optimal weights'
]
colors = [
    (0.21568627450980393, 0.49411764705882355, 0.7215686274509804),
    (1.0, 0.4980392156862745, 0.0),
    'k',
    'r'
]

# Create figure
fig = plt.figure(figsize=(10, 1))
ax = fig.add_subplot(1, 1, 1)

# Create legend handles
handles = [mpatches.Patch(color=color, label=category) for color, category in zip(colors, categories)]

# --- Create combined legend with title on first line ---
legend = ax.legend(
    handles=handles,
    title="Method",
    loc='center',
    bbox_to_anchor=(0.5, 0.5),
    ncol=4,  # put entries in one row under the title
    frameon=True,
    fancybox=False,
    edgecolor='0.7',        # same grey border
    facecolor='white',      # white background
    handletextpad=1.5,
    borderaxespad=0
)

# Style the title
legend.get_title().set_fontsize('large')
legend.get_title().set_fontweight('bold')
legend._legend_box.align = "center"  # center the title horizontally

# Remove axes
ax.axis('off')

# Save and show
plt.savefig("legend_weighted.pdf", format="pdf", bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# Sample data for legend
categories = ['i-Rock', 'weighted two-step', 'two-step w. true optimal weights']
colors = [(0.21568627450980393, 0.49411764705882355, 0.7215686274509804), 'k', 'r']

# Create a figure
fig = plt.figure(figsize=(10, 0.5))
ax = fig.add_subplot(1, 1, 1)

# Create legend handles
handles = [mpatches.Patch(color=color, label=category) for color, category in zip(colors, categories)]

# Add an invisible handle for the title
title_handle = mpatches.Patch(color='none', label='Method')

# Add the legend to the plot
legend = ax.legend(
    handles=[title_handle] + handles,
    loc='center', 
    bbox_to_anchor=(0.5, 0.5), 
    ncol=len(categories) + 1,
    handletextpad=1.5, 
    borderaxespad=0
)

# Customize the legend title
legend.get_texts()[0].set_fontsize('large')
legend.get_texts()[0].set_fontweight('bold')
#legend.get_texts()[0].set_color('red')

# Remove the axes
ax.axis('off')

# Save the plot
plt.savefig("legend_weighted2.pdf", format="pdf")

# Show the plot (optional)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# Sample data for legend
categories = ['i-Rock', 'quantile average', 'two-step']
colors = [(0.21568627450980393, 0.49411764705882355, 0.7215686274509804), 'k', (0.30196078431372547, 0.6862745098039216, 0.2901960784313726)]

# Create a figure
fig = plt.figure(figsize=(12, 0.5))
ax = fig.add_subplot(1, 1, 1)

# Create legend handles
handles = [mpatches.Patch(color=color, label=category) for color, category in zip(colors, categories)]

# Add an invisible handle for the title
title_handle = mpatches.Patch(color='none', label='Method')

# Add the legend to the plot
legend = ax.legend(
    handles=[title_handle] + handles,
    loc='center', 
    bbox_to_anchor=(0.5, 0.5), 
    ncol=len(categories) + 1,
    handletextpad=1.5, 
    borderaxespad=0
)

# Customize the legend title
legend.get_texts()[0].set_fontsize('large')
legend.get_texts()[0].set_fontweight('bold')
#legend.get_texts()[0].set_color('red')

# Remove the axes
ax.axis('off')

# Save the plot
plt.savefig("legend3.pdf", format="pdf")

# Show the plot (optional)
plt.show()

# %%
data = pd.read_csv("results/results_2d_disjoint_weight.csv")
data = data[(data["n"]==10000)&(data["tau"]==0.9)]
data_global = data[(data["Method"]=="mRock_kNN_global_linear_Neyman")&(data["num_bin"]==150)]
### tau = 0.8
beta0 = data_global["beta0"]/np.sqrt(2.463485/n)
beta1 = data_global["beta1"]/np.sqrt(1.3690273/n)
beta2 = data_global["beta2"]/np.sqrt(7.6330206/n)
### tau = 0.9
# beta0 = data_global["beta0"]/np.sqrt(1.3404259/n)
# beta1 = data_global["beta1"]/np.sqrt(0.7449119/n)
# beta2 = data_global["beta2"]/np.sqrt(4.1532612/n)
###
# beta0 = data_global["beta0"]/np.sqrt(3.878542/n)
# beta1 = data_global["beta1"]/np.sqrt(1.8988038/n)
# beta2 = data_global["beta2"]/np.sqrt(4.4017361/n)
# get the figure object
fig = plt.figure(figsize=(8, 8))

# first subplot
ax1 = fig.add_subplot(2,2,1)
ax1 = pg.qqplot(beta0, dist='norm', confidence=.95)
#sm.qqplot(beta0, line='45', ax=ax1)
ax1.set_title(r'Q-Q Plot for $\hat \beta_0/\sigma_0^*$')

# second subplot
ax2 = fig.add_subplot(2,2,2)
ax2 = pg.qqplot(beta1, dist='norm', confidence=.95)
#sm.qqplot(beta1, line='45', ax=ax2)
ax2.set_title(r'Q-Q Plot for $\hat \beta_1/\sigma_1^*$')

ax3 = fig.add_subplot(2,2,3)
ax3 = pg.qqplot(beta2, dist='norm', confidence=.95)
#sm.qqplot(beta1, line='45', ax=ax2)
ax3.set_title(r'Q-Q Plot for $\hat \beta_2/\sigma_2^*$')


# show the plot
plt.tight_layout()
#plt.savefig("1dim_qqplot.pdf", format="pdf")

# %%
data = pd.read_csv("results/results_2d_disjoint_weight.csv")
data = data[(data["n"]==3000)&(data["tau"]==0.9)]
n = 3000
data_global = data[(data["Method"]=="mRock_kNN_bs_Neyman")&(data["num_bin"]==75)]
### tau = 0.9
beta0 = data_global["beta0"]/np.sqrt(1.3404259/n)
beta1 = data_global["beta1"]/np.sqrt(0.7449119/n)
beta2 = data_global["beta2"]/np.sqrt(4.1532612/n)
loc, scale = 0, 1
#loc, scale = np.mean(beta0), np.std(beta0, ddof=1)
cdf0 = stats.norm(loc, scale).cdf
p.append(stats.ks_1samp(beta0, cdf0)[1])
print(stats.ks_1samp(beta0, cdf0)[1])
#loc, scale = np.mean(beta1), np.std(beta1, ddof=1)
cdf1 = stats.norm(loc, scale).cdf
p.append(stats.ks_1samp(beta1, cdf1)[1])
print(stats.ks_1samp(beta1, cdf1)[1])
#loc, scale = np.mean(beta2), np.std(beta2, ddof=1)
cdf2 = stats.norm(loc, scale).cdf
p.append(stats.ks_1samp(beta2, cdf2)[1])
print(stats.ks_1samp(beta2, cdf2)[1])
# Out:
# 0.018389884840886554
# 0.982870861113856
# 0.012138650421890532

# %%
p = []
data = pd.read_csv("results/results_2d_disjoint_final.csv")

data_global = data[(data["n"]==10000)&(data["tau"]==0.9)]
n = 10000
data_global = data_global[(data_global["Method"]=="mRock_kNN_bs_Neyman")&(data_global["num_bin"]==7)]
### tau = 0.9
beta0 = data_global["beta0"]/np.sqrt(1.3404259/n)
beta1 = data_global["beta1"]/np.sqrt(0.7449119/n)
beta2 = data_global["beta2"]/np.sqrt(4.1532612/n)
loc, scale = 0, 1
#loc, scale = np.mean(beta0), np.std(beta0, ddof=1)
cdf0_10000_9 = stats.norm(loc, scale).cdf
p.append(stats.ks_1samp(beta0, cdf0_10000_9)[1])
#loc, scale = np.mean(beta1), np.std(beta1, ddof=1)
cdf1_10000_9 = stats.norm(loc, scale).cdf
p.append(stats.ks_1samp(beta1, cdf1_10000_9)[1])
#loc, scale = np.mean(beta2), np.std(beta2, ddof=1)
cdf2_10000_9 = stats.norm(loc, scale).cdf
p.append(stats.ks_1samp(beta2, cdf2_10000_9)[1])

data_global = data[(data["n"]==5000)&(data["tau"]==0.9)]
n = 5000
data_global = data_global[(data_global["Method"]=="mRock_kNN_bs_Neyman")&(data_global["num_bin"]==6)]
### tau = 0.9
beta0 = data_global["beta0"]/np.sqrt(1.3404259/n)
beta1 = data_global["beta1"]/np.sqrt(0.7449119/n)
beta2 = data_global["beta2"]/np.sqrt(4.1532612/n)
loc, scale = 0, 1
#loc, scale = np.mean(beta0), np.std(beta0, ddof=1)
cdf0_5000_9 = stats.norm(loc, scale).cdf
p.append(stats.ks_1samp(beta0, cdf0_5000_9)[1])
#loc, scale = np.mean(beta1), np.std(beta1, ddof=1)
cdf1_5000_9 = stats.norm(loc, scale).cdf
p.append(stats.ks_1samp(beta1, cdf1_5000_9)[1])
#loc, scale = np.mean(beta2), np.std(beta2, ddof=1)
cdf2_5000_9 = stats.norm(loc, scale).cdf
p.append(stats.ks_1samp(beta2, cdf2_5000_9)[1])

data_global = data[(data["n"]==10000)&(data["tau"]==0.8)]
n = 10000
data_global = data_global[(data_global["Method"]=="mRock_kNN_bs_Neyman")&(data_global["num_bin"]==7)]
### tau = 0.8
beta0 = data_global["beta0"]/np.sqrt(2.463485/n)
beta1 = data_global["beta1"]/np.sqrt(1.3690273/n)
beta2 = data_global["beta2"]/np.sqrt(7.6330206/n)
loc, scale = 0, 1
#loc, scale = np.mean(beta0), np.std(beta0, ddof=1)
cdf0_10000_8 = stats.norm(loc, scale).cdf
p.append(stats.ks_1samp(beta0, cdf0_10000_8)[1])
#loc, scale = np.mean(beta1), np.std(beta1, ddof=1)
cdf1_10000_8 = stats.norm(loc, scale).cdf
p.append(stats.ks_1samp(beta1, cdf1_10000_8)[1])
#loc, scale = np.mean(beta2), np.std(beta2, ddof=1)
cdf2_10000_8 = stats.norm(loc, scale).cdf
p.append(stats.ks_1samp(beta2, cdf2_10000_8)[1])

data_global = data[(data["n"]==5000)&(data["tau"]==0.8)]
n = 5000
data_global = data_global[(data_global["Method"]=="mRock_kNN_bs_Neyman")&(data_global["num_bin"]==6)]
### tau = 0.8
beta0 = data_global["beta0"]/np.sqrt(2.463485/n)
beta1 = data_global["beta1"]/np.sqrt(1.3690273/n)
beta2 = data_global["beta2"]/np.sqrt(7.6330206/n)
loc, scale = 0, 1
#loc, scale = np.mean(beta0), np.std(beta0, ddof=1)
cdf0_5000_8 = stats.norm(loc, scale).cdf
p.append(stats.ks_1samp(beta0, cdf0_5000_8)[1])
#loc, scale = np.mean(beta1), np.std(beta1, ddof=1)
cdf1_5000_8 = stats.norm(loc, scale).cdf
p.append(stats.ks_1samp(beta1, cdf1_5000_8)[1])
#loc, scale = np.mean(beta2), np.std(beta2, ddof=1)
cdf2_5000_8 = stats.norm(loc, scale).cdf
p.append(stats.ks_1samp(beta2, cdf2_5000_8)[1])

# %%
cdf_unif = stats.uniform(0,1).cdf
stats.ks_1samp(p,cdf_unif)[1]
# Out:
# 0.9937056423835477

# %%
data = pd.read_csv("results/results_2d_disjoint_weight.csv")
data = data[(data["n"]==10000)&(data["tau"]==0.9)]
n = 10000
data_global = data[(data["Method"]=="mRock_kNN_bs_Neyman")&(data["num_bin"]==150)]
### tau = 0.9
beta0 = data_global["beta0"]/np.sqrt(1.3404259/n)
beta1 = data_global["beta1"]/np.sqrt(0.7449119/n)
beta2 = data_global["beta2"]/np.sqrt(4.1532612/n)
loc, scale = 0, 1
#loc, scale = np.mean(beta0), np.std(beta0, ddof=1)
cdf0_10000_9 = stats.norm(loc, scale).cdf
print(stats.ks_1samp(beta0, cdf0_10000_9))
#loc, scale = np.mean(beta1), np.std(beta1, ddof=1)
cdf1_10000_9 = stats.norm(loc, scale).cdf
print(stats.ks_1samp(beta1, cdf1_10000_9))
#loc, scale = np.mean(beta2), np.std(beta2, ddof=1)
cdf2_10000_9 = stats.norm(loc, scale).cdf
print(stats.ks_1samp(beta2, cdf2_10000_9))
# Out:
# KstestResult(statistic=0.05458351915767823, pvalue=0.09794078816002794, statistic_location=1.0303772217907237, statistic_sign=-1)
# KstestResult(statistic=0.03941212666902222, pvalue=0.408593444065283, statistic_location=-0.06167172994417885, statistic_sign=-1)
# KstestResult(statistic=0.04353720048874246, pvalue=0.2910037451524021, statistic_location=-1.1529629330863738, statistic_sign=1)

# %%
n = 5000
data = pd.read_csv("results/results_2d_disjoint_weight.csv")
data = data[(data["n"]==5000)&(data["tau"]==0.8)]
data_global = data[(data["Method"]=="mRock_kNN_bs_Neyman")&(data["num_bin"]==75)]
### tau = 0.8
beta0 = data_global["beta0"]/np.sqrt(2.463485/n)
beta1 = data_global["beta1"]/np.sqrt(1.3690273/n)
beta2 = data_global["beta2"]/np.sqrt(7.6330206/n)
loc, scale = 0, 1
#loc, scale = np.mean(beta0), np.std(beta0, ddof=1)
cdf0_5000_8 = stats.norm(loc, scale).cdf
print(stats.ks_1samp(beta0, cdf0_5000_8))
#loc, scale = np.mean(beta1), np.std(beta1, ddof=1)
cdf1_5000_8 = stats.norm(loc, scale).cdf
print(stats.ks_1samp(beta1, cdf1_5000_8))
#loc, scale = np.mean(beta2), np.std(beta2, ddof=1)
cdf2_5000_8 = stats.norm(loc, scale).cdf
print(stats.ks_1samp(beta2, cdf2_5000_8))
# Out:
# KstestResult(statistic=0.031784382965250435, pvalue=0.6810733534351895, statistic_location=0.9069537904396174, statistic_sign=-1)
# KstestResult(statistic=0.03551843372876745, pvalue=0.5416295862048035, statistic_location=-0.5873582422633495, statistic_sign=1)
# KstestResult(statistic=0.028462074993992115, pvalue=0.8017081552765378, statistic_location=0.19559886337936677, statistic_sign=1)

# %%
data = pd.read_csv("results/results_2d_disjoint_weight.csv")
data = data[(data["n"]==10000)&(data["tau"]==0.8)]
n = 10000
data_global = data[(data["Method"]=="mRock_kNN_bs_Neyman")&(data["num_bin"]==200)]
### tau = 0.8
beta0 = data_global["beta0"]/np.sqrt(2.463485/n)
beta1 = data_global["beta1"]/np.sqrt(1.3690273/n)
beta2 = data_global["beta2"]/np.sqrt(7.6330206/n)
loc, scale = 0, 1
#loc, scale = np.mean(beta0), np.std(beta0, ddof=1)
cdf0_10000_8 = stats.norm(loc, scale).cdf
print(stats.ks_1samp(beta0, cdf0_10000_8))
#loc, scale = np.mean(beta1), np.std(beta1, ddof=1)
cdf1_10000_8 = stats.norm(loc, scale).cdf
print(stats.ks_1samp(beta1, cdf1_10000_8))
#loc, scale = np.mean(beta2), np.std(beta2, ddof=1)
cdf2_10000_8 = stats.norm(loc, scale).cdf
print(stats.ks_1samp(beta2, cdf2_10000_8))
# Out:
# KstestResult(statistic=0.04869992363283571, pvalue=0.18051489369033213, statistic_location=1.28555000987611, statistic_sign=-1)
# KstestResult(statistic=0.030423239581209183, pvalue=0.7318212643607855, statistic_location=0.14697276042610635, statistic_sign=-1)
# KstestResult(statistic=0.019882495081621876, pvalue=0.9868553442212826, statistic_location=-0.5884429594003349, statistic_sign=1)

# %%
p = [stats.ks_1samp(beta0, cdf0)[1],stats.ks_1samp(beta0, cdf1)[1],stats.ks_1samp(beta0, cdf2)[1]]
print(stats.ks_1samp(beta2, cdf2_10000_8))

# %% [markdown]
# ## 1 dim Guassian

# %%
data = pd.read_csv("results/results_1d.csv")
data_group = data.drop(columns=["seed","p","time"]).groupby(["n","tau","Method","num_bin"])
bias = data_group.mean().reset_index()
std = data_group.std().reset_index()
RMSE = np.sqrt(data_group.apply(lambda x: (x**2).mean())).reset_index()
data_group_other = data[np.isnan(data["num_bin"])].drop(columns=["seed","p","time","num_bin"]).groupby(["n","tau","Method"])
bias_other = data_group_other.mean().reset_index()
std_other = data_group_other.std().reset_index()
RMSE_other = np.sqrt(data_group_other.apply(lambda x: (x**2).mean())).reset_index()

# %%
data = pd.read_csv("results/results_1d.csv")
num_bin = 7
data_group = data.drop(columns=["seed","p","time","tau"]).groupby(["Method","n","num_bin"])
bias = data_group.mean().reset_index()
std = data_group.std().reset_index()
RMSE = np.sqrt(data_group.apply(lambda x: (x**2).mean())).reset_index()
data_group_other = data[np.isnan(data["num_bin"])].drop(columns=["seed","p","tau","time","num_bin"]).groupby(["Method","n"])
bias_other = data_group_other.mean().reset_index()
std_other = data_group_other.std().reset_index()
RMSE_other = np.sqrt(data_group_other.apply(lambda x: (x**2).mean())).reset_index()

bias = bias[bias["num_bin"]==num_bin]
std = std[std["num_bin"]==num_bin]
RMSE = RMSE[RMSE["num_bin"]==num_bin]
methods_to_filter = ["mRock_kNN_global_linear_Neyman","mRock_kNN_bs_Neyman"]
bias_irock = bias[(bias["Method"].isin(methods_to_filter))].drop(columns="num_bin")#.set_index(['n','Method'])
bias_2step = bias_other[bias_other["Method"].isin(["two_step_Neyman","Average of linear quantiles"])]
# bias_2step["Method"]="two-step"
bias_wide = pd.concat([bias_irock,bias_2step])
# bias_wide = bias_wide.reset_index()
replacements={"mRock_kNN_global_linear_Neyman":"i-Rock w. linear quantile",
    "mRock_kNN_bs_Neyman":"i-Rock w. B-spline quantile",
                      #"local_adjust":"i-Rock w. local linear quantile (adjusted)",
                      "two_step_Neyman":"two-step",
             "Average of linear quantiles":"quantile average"}
bias_wide["Method"] = bias_wide["Method"].replace(replacements)
bias_long = pd.melt(bias_wide.drop(columns='n'), id_vars=['Method'])
std_irock = std[(std["Method"].isin(methods_to_filter))].drop(columns="num_bin")
std_2step = std_other[std_other["Method"].isin(["two_step_Neyman","Average of linear quantiles"])]
std_wide = pd.concat([std_irock,std_2step])
std_wide["Method"] = std_wide["Method"].replace(replacements)
std_long = pd.melt(std_wide.drop(columns='n'), id_vars=['Method'])
bias_std = bias_long
bias_std["value"] = bias_long["value"]/std_long["value"]
replacements={"beta0":r"$\beta_0$",
             "beta1":r"$\beta_1$",
             "beta2":r"$\beta_2$"}
bias_std["variable"] = bias_std["variable"].replace(replacements)
RMSE_irock = RMSE[(RMSE["Method"].isin(methods_to_filter))].drop(columns="num_bin")
RMSE_2step = RMSE_other[(RMSE_other["Method"]=="two_step_Neyman")].drop(columns=["Method","n"]).reset_index(drop=True)
RMSE_gl = RMSE_2step/RMSE_irock[RMSE_irock["Method"]=="mRock_kNN_global_linear_Neyman"].drop(columns=["Method","n"]).reset_index(drop=True)
RMSE_gl["Method"]="i-Rock w. linear quantile"
#RMSE_gl_ad = RMSE_2step/RMSE_irock[RMSE_irock["Method"]=="global_linear_adjust"].drop(columns=["Method","n"]).reset_index(drop=True)
#RMSE_gl_ad["Method"]="i-Rock w. linear quantile (adjusted)"
#RMSE_lc = RMSE_2step/RMSE_irock[RMSE_irock["Method"]=="local_adjust"].drop(columns=["Method","n"]).reset_index(drop=True)
#RMSE_lc["Method"]="i-Rock w. local linear quantile (adjusted)"
RMSE_bs = RMSE_2step/RMSE_irock[RMSE_irock["Method"]=="mRock_kNN_bs_Neyman"].drop(columns=["Method","n"]).reset_index(drop=True)
RMSE_bs["Method"]="i-Rock w. B-spline quantile"
RMSE_mean_quantile = RMSE_2step/RMSE_other[(RMSE_other["Method"]=="Average of linear quantiles")].drop(columns=["Method","n"]).reset_index(drop=True)
RMSE_mean_quantile["Method"]="quantile average"
RMSE_wide = pd.concat([RMSE_gl,RMSE_bs,RMSE_mean_quantile])
RMSE_long = pd.melt(RMSE_wide, id_vars=['Method'])
replacements={"beta0":r"$\beta_0$",
             "beta1":r"$\beta_1$",
             "beta2":r"$\beta_2$"}
RMSE_long["variable"] = RMSE_long["variable"].replace(replacements)

# %%
fig = plt.figure(figsize=(9, 4))
ax = fig.add_subplot(1,2,1)
custom_colors = {
    'i-Rock w. linear quantile': (0.21568627450980393, 0.49411764705882355, 0.7215686274509804),   
    'i-Rock w. B-spline quantile': (1.0, 0.4980392156862745, 0.0),  
    'two-step': (0.30196078431372547, 0.6862745098039216, 0.2901960784313726),
    'quantile average': 'k'
}
custom_order = ['i-Rock w. linear quantile', 'i-Rock w. B-spline quantile','quantile average','two-step']
sns.barplot(data=bias_std, x='variable', y='value', hue='Method', palette=custom_colors, hue_order=custom_order)
# Add labels
plt.xlabel('Coefficients')
plt.ylabel('Relative bias')
#plt.legend()#title='Method')
#ax.legend_.remove()

ax = fig.add_subplot(1,2,2)
custom_colors = {
    'i-Rock w. linear quantile': (0.21568627450980393, 0.49411764705882355, 0.7215686274509804),   
    'i-Rock w. B-spline quantile': (1.0, 0.4980392156862745, 0.0),
    'quantile average': 'k'
}
custom_order = ['i-Rock w. linear quantile', 'i-Rock w. B-spline quantile','quantile average']
sns.barplot(data=RMSE_long, x='variable', y='value', hue='Method',palette=custom_colors, hue_order=custom_order)
# Set y-axis limits
#plt.ylim(0, 2)
ax.axhline(y=1, color=(0.30196078431372547, 0.6862745098039216, 0.2901960784313726), linestyle='--',label='two-step')
# Add labels and a legend
plt.xlabel('Coefficients')
plt.ylabel('RMSE ratio')
ax.legend_.remove()
#plt.legend(title='Method',bbox_to_anchor = (1, 0.5))
#handles, labels = ax.get_legend_handles_labels()
#new_order = [1, 2, 0]  # Assuming 'two-step' is the second entry
#ax.legend([handles[i] for i in new_order], [labels[i] for i in new_order])#, title='Method')#, bbox_to_anchor=(1, 0.5))
#ax.legend(title='Method', bbox_to_anchor=(1, 0.5))
fig.tight_layout()
#plt.savefig("2dim_4methods_n5000_tau9.pdf", format="pdf")

# %%
data = pd.read_csv("results/results_1d.csv")
data = data[(data["n"]==10000)&(data["tau"]==0.8)]
num_bin = 17
data_group = data.drop(columns=["seed","p","time","tau"]).groupby(["Method","n","num_bin"])
bias = data_group.mean().reset_index()
std = data_group.std().reset_index()
RMSE = np.sqrt(data_group.apply(lambda x: (x**2).mean())).reset_index()
data_group_other = data[np.isnan(data["num_bin"])].drop(columns=["seed","p","tau","time","num_bin"]).groupby(["Method","n"])
bias_other = data_group_other.mean().reset_index()
std_other = data_group_other.std().reset_index()
RMSE_other = np.sqrt(data_group_other.apply(lambda x: (x**2).mean())).reset_index()

bias = bias[bias["num_bin"]==num_bin]
std = std[std["num_bin"]==num_bin]
RMSE = RMSE[RMSE["num_bin"]==num_bin]
methods_to_filter = ["mRock_kNN_global_linear_Neyman","mRock_kNN_bs_Neyman"]
bias_irock = bias[(bias["Method"].isin(methods_to_filter))].drop(columns="num_bin")#.set_index(['n','Method'])
bias_2step = bias_other[bias_other["Method"].isin(["two_step_Neyman","Average of linear quantiles"])]
# bias_2step["Method"]="two-step"
bias_wide = pd.concat([bias_irock,bias_2step])
# bias_wide = bias_wide.reset_index()
replacements={"mRock_kNN_global_linear_Neyman":"i-Rock w. linear quantile",
    "mRock_kNN_bs_Neyman":"i-Rock w. B-spline quantile",
                      #"local_adjust":"i-Rock w. local linear quantile (adjusted)",
                      "two_step_Neyman":"two-step",
             "Average of linear quantiles":"quantile average"}
bias_wide["Method"] = bias_wide["Method"].replace(replacements)
bias_long = pd.melt(bias_wide.drop(columns='n'), id_vars=['Method'])
std_irock = std[(std["Method"].isin(methods_to_filter))].drop(columns="num_bin")
std_2step = std_other[std_other["Method"].isin(["two_step_Neyman","Average of linear quantiles"])]
std_wide = pd.concat([std_irock,std_2step])
std_wide["Method"] = std_wide["Method"].replace(replacements)
std_long = pd.melt(std_wide.drop(columns='n'), id_vars=['Method'])
bias_std = bias_long
bias_std["value"] = bias_long["value"]/std_long["value"]
replacements={"beta0":r"$\beta_0$",
             "beta1":r"$\beta_1$",
             "beta2":r"$\beta_2$"}
bias_std["variable"] = bias_std["variable"].replace(replacements)
RMSE_irock = RMSE[(RMSE["Method"].isin(methods_to_filter))].drop(columns="num_bin")
RMSE_2step = RMSE_other[(RMSE_other["Method"]=="two_step_Neyman")].drop(columns=["Method","n"]).reset_index(drop=True)
RMSE_gl = RMSE_2step/RMSE_irock[RMSE_irock["Method"]=="mRock_kNN_global_linear_Neyman"].drop(columns=["Method","n"]).reset_index(drop=True)
RMSE_gl["Method"]="i-Rock w. linear quantile"
#RMSE_gl_ad = RMSE_2step/RMSE_irock[RMSE_irock["Method"]=="global_linear_adjust"].drop(columns=["Method","n"]).reset_index(drop=True)
#RMSE_gl_ad["Method"]="i-Rock w. linear quantile (adjusted)"
#RMSE_lc = RMSE_2step/RMSE_irock[RMSE_irock["Method"]=="local_adjust"].drop(columns=["Method","n"]).reset_index(drop=True)
#RMSE_lc["Method"]="i-Rock w. local linear quantile (adjusted)"
RMSE_bs = RMSE_2step/RMSE_irock[RMSE_irock["Method"]=="mRock_kNN_bs_Neyman"].drop(columns=["Method","n"]).reset_index(drop=True)
RMSE_bs["Method"]="i-Rock w. B-spline quantile"
RMSE_mean_quantile = RMSE_2step/RMSE_other[(RMSE_other["Method"]=="Average of linear quantiles")].drop(columns=["Method","n"]).reset_index(drop=True)
RMSE_mean_quantile["Method"]="quantile average"
RMSE_wide = pd.concat([RMSE_gl,RMSE_bs,RMSE_mean_quantile])
RMSE_long = pd.melt(RMSE_wide, id_vars=['Method'])
replacements={"beta0":r"$\beta_0$",
             "beta1":r"$\beta_1$",
             "beta2":r"$\beta_2$"}
RMSE_long["variable"] = RMSE_long["variable"].replace(replacements)

# %%
fig = plt.figure(figsize=(9, 4))
ax = fig.add_subplot(1,2,1)
custom_colors = {
    'i-Rock w. linear quantile': (0.21568627450980393, 0.49411764705882355, 0.7215686274509804),   
    'i-Rock w. B-spline quantile': (1.0, 0.4980392156862745, 0.0),  
    'two-step': (0.30196078431372547, 0.6862745098039216, 0.2901960784313726),
    'quantile average': 'k'
}
custom_order = ['i-Rock w. linear quantile', 'i-Rock w. B-spline quantile','quantile average','two-step']
sns.barplot(data=bias_std, x='variable', y='value', hue='Method', palette=custom_colors, hue_order=custom_order)
# Add labels
plt.xlabel('Coefficients')
plt.ylabel('Relative bias')
#plt.legend()#title='Method')
ax.legend_.remove()

ax = fig.add_subplot(1,2,2)
custom_colors = {
    'i-Rock w. linear quantile': (0.21568627450980393, 0.49411764705882355, 0.7215686274509804),   
    'i-Rock w. B-spline quantile': (1.0, 0.4980392156862745, 0.0),
    'quantile average': 'k'
}
custom_order = ['i-Rock w. linear quantile', 'i-Rock w. B-spline quantile','quantile average']
sns.barplot(data=RMSE_long, x='variable', y='value', hue='Method',palette=custom_colors, hue_order=custom_order)
# Set y-axis limits
#plt.ylim(0, 2)
ax.axhline(y=1, color=(0.30196078431372547, 0.6862745098039216, 0.2901960784313726), linestyle='--',label='two-step')
# Add labels and a legend
plt.xlabel('Coefficients')
plt.ylabel('RMSE ratio')
ax.legend_.remove()
#plt.legend(title='Method',bbox_to_anchor = (1, 0.5))
#handles, labels = ax.get_legend_handles_labels()
#new_order = [1, 2, 0]  # Assuming 'two-step' is the second entry
#ax.legend([handles[i] for i in new_order], [labels[i] for i in new_order])#, title='Method')#, bbox_to_anchor=(1, 0.5))
#ax.legend(title='Method', bbox_to_anchor=(1, 0.5))
fig.tight_layout()
plt.savefig("1dim_Gaussian_10000_08.pdf", format="pdf")

# %%
data = pd.read_csv("results/results_1d.csv")
data = data[(data["n"]==10000)&(data["tau"]==0.9)]
num_bin = 17
data_group = data.drop(columns=["seed","p","time","tau"]).groupby(["Method","n","num_bin"])
bias = data_group.mean().reset_index()
std = data_group.std().reset_index()
RMSE = np.sqrt(data_group.apply(lambda x: (x**2).mean())).reset_index()
data_group_other = data[np.isnan(data["num_bin"])].drop(columns=["seed","p","tau","time","num_bin"]).groupby(["Method","n"])
bias_other = data_group_other.mean().reset_index()
std_other = data_group_other.std().reset_index()
RMSE_other = np.sqrt(data_group_other.apply(lambda x: (x**2).mean())).reset_index()

bias = bias[bias["num_bin"]==num_bin]
std = std[std["num_bin"]==num_bin]
RMSE = RMSE[RMSE["num_bin"]==num_bin]
methods_to_filter = ["mRock_kNN_global_linear_Neyman","mRock_kNN_bs_Neyman"]
bias_irock = bias[(bias["Method"].isin(methods_to_filter))].drop(columns="num_bin")#.set_index(['n','Method'])
bias_2step = bias_other[bias_other["Method"].isin(["two_step_Neyman"])]
# bias_2step["Method"]="two-step"
bias_wide = pd.concat([bias_irock,bias_2step])
# bias_wide = bias_wide.reset_index()
replacements={"mRock_kNN_global_linear_Neyman":"i-Rock w. linear quantile",
    "mRock_kNN_bs_Neyman":"i-Rock w. B-spline quantile",
                      #"local_adjust":"i-Rock w. local linear quantile (adjusted)",
                      "two_step_Neyman":"two-step"}
bias_wide["Method"] = bias_wide["Method"].replace(replacements)
bias_long = pd.melt(bias_wide.drop(columns='n'), id_vars=['Method'])
std_irock = std[(std["Method"].isin(methods_to_filter))].drop(columns="num_bin")
std_2step = std_other[std_other["Method"].isin(["two_step_Neyman"])]
std_wide = pd.concat([std_irock,std_2step])
std_wide["Method"] = std_wide["Method"].replace(replacements)
std_long = pd.melt(std_wide.drop(columns='n'), id_vars=['Method'])
bias_std = bias_long
bias_std["value"] = bias_long["value"]/std_long["value"]
replacements={"beta0":r"$\beta_0$",
             "beta1":r"$\beta_1$",
             "beta2":r"$\beta_2$"}
bias_std["variable"] = bias_std["variable"].replace(replacements)
RMSE_irock = RMSE[(RMSE["Method"].isin(methods_to_filter))].drop(columns="num_bin")
RMSE_2step = RMSE_other[(RMSE_other["Method"]=="two_step_Neyman")].drop(columns=["Method","n"]).reset_index(drop=True)
RMSE_gl = RMSE_2step/RMSE_irock[RMSE_irock["Method"]=="mRock_kNN_global_linear_Neyman"].drop(columns=["Method","n"]).reset_index(drop=True)
RMSE_gl["Method"]="i-Rock w. linear quantile"
#RMSE_gl_ad = RMSE_2step/RMSE_irock[RMSE_irock["Method"]=="global_linear_adjust"].drop(columns=["Method","n"]).reset_index(drop=True)
#RMSE_gl_ad["Method"]="i-Rock w. linear quantile (adjusted)"
#RMSE_lc = RMSE_2step/RMSE_irock[RMSE_irock["Method"]=="local_adjust"].drop(columns=["Method","n"]).reset_index(drop=True)
#RMSE_lc["Method"]="i-Rock w. local linear quantile (adjusted)"
RMSE_bs = RMSE_2step/RMSE_irock[RMSE_irock["Method"]=="mRock_kNN_bs_Neyman"].drop(columns=["Method","n"]).reset_index(drop=True)
RMSE_bs["Method"]="i-Rock w. B-spline quantile"
RMSE_wide = pd.concat([RMSE_gl,RMSE_bs])
RMSE_long = pd.melt(RMSE_wide, id_vars=['Method'])
replacements={"beta0":r"$\beta_0$",
             "beta1":r"$\beta_1$",
             "beta2":r"$\beta_2$"}
RMSE_long["variable"] = RMSE_long["variable"].replace(replacements)

# %%
fig = plt.figure(figsize=(9, 4))
ax = fig.add_subplot(1,2,1)
custom_colors = {
    'i-Rock w. linear quantile': (0.21568627450980393, 0.49411764705882355, 0.7215686274509804),   
    'i-Rock w. B-spline quantile': (1.0, 0.4980392156862745, 0.0),  
    'two-step': (0.30196078431372547, 0.6862745098039216, 0.2901960784313726)
}
custom_order = ['i-Rock w. linear quantile', 'i-Rock w. B-spline quantile','two-step']
sns.barplot(data=bias_std, x='variable', y='value', hue='Method', palette=custom_colors, hue_order=custom_order)
# Add labels
plt.xlabel('Coefficients')
plt.ylabel('Relative bias')
#plt.legend()#title='Method')
ax.legend_.remove()

ax = fig.add_subplot(1,2,2)
custom_colors = {
    'i-Rock w. linear quantile': (0.21568627450980393, 0.49411764705882355, 0.7215686274509804),   
    'i-Rock w. B-spline quantile': (1.0, 0.4980392156862745, 0.0)
}
custom_order = ['i-Rock w. linear quantile', 'i-Rock w. B-spline quantile']
sns.barplot(data=RMSE_long, x='variable', y='value', hue='Method',palette=custom_colors, hue_order=custom_order)
# Set y-axis limits
#plt.ylim(0, 2)
ax.axhline(y=1, color=(0.30196078431372547, 0.6862745098039216, 0.2901960784313726), linestyle='--',label='two-step')
# Add labels and a legend
plt.xlabel('Coefficients')
plt.ylabel('RMSE ratio')
ax.legend_.remove()
#plt.legend(title='Method',bbox_to_anchor = (1, 0.5))
#handles, labels = ax.get_legend_handles_labels()
#new_order = [1, 2, 0]  # Assuming 'two-step' is the second entry
#ax.legend([handles[i] for i in new_order], [labels[i] for i in new_order])#, title='Method')#, bbox_to_anchor=(1, 0.5))
#ax.legend(title='Method', bbox_to_anchor=(1, 0.5))
fig.tight_layout()
plt.savefig("1dim_Gaussian_10000_09.pdf", format="pdf")
